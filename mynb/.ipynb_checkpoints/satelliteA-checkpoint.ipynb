# %% [markdown]
# ##Satellite exercise for Wed. Jan. 14

# %% [markdown]
# Objectives:  Download, read and plot a month of level 3 ocean color data (Chorlophyl A) and get started with the binned version of the same dataset

# %% [markdown]
# Getting started:
#
# Open a bash shell (OSX terminal) and
#
# ``` bash
# > cd xxx (where xxx is the notebooks directory of your forked and cloned repository
# > git branch  (to see which branch you're on)
# > git status (to see whether any files have been editied (hopefully never on master)
# > git pull  (to bring in my new code for today)
# > git checkout -b working (to start a new working branch)
# > git push origin working (to backup new branch to github)
# > cd notebooks
# > ipython notebook satelliteA.ipynb  (to get started on your copy)
# ```

# %%
import glob  #this module gets file names using wildcards
#
# the h5dump.py file is one folder up in the utilities folder
# use site.addsitedir to add this folder to the list of folders
# python searches for imports
#
import site
site.addsitedir('../utilities')
from h5dump import dumph5
import h5py
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %% [markdown]
# 1.  Look at the product definitions for level 2 and level 3 data at http://oceancolor.gsfc.nasa.gov/cms/products
# 2.  Find a month of level 3 chlorophyll concentration data for the Modis instrument from http://oceancolor.gsfc.nasa.gov/cgi/l3
# 3.  Download the bz2 zipped files for the Standard Mapped Image and binned data to a folder called dataset
# 4.  unzip the two files with bunzip2
# 5.  Convert hdf4 to hdf5 with http://www.hdfgroup.org/h4toh5/download.html or http://hdfeos.org/software/h4toh5/bin/mac/

# %% [markdown]
# The following module, h5dump.py in the utilities directory, uses the [visititems](http://docs.h5py.org/en/latest/quick.html) of the h5py module to walk the hdf5 file and print all variables and attributes

# %% [markdown]
# ```python
# #!/usr/bin/env python
# from __future__ import print_function
# import h5py
# import argparse
# import types
#
# def print_attrs(name, obj):
#     print("item name: ",name,repr(obj))
#     for key, val in obj.attrs.iteritems():
#         print("    %s: %s" % (key, val))
#
# def dumph5(filename):
#     #
#     # make sure that have a filename, not an open file
#     #
#     if isinstance(filename,h5py._hl.files.File):
#         raise Exception('need simple filename')
#     with  h5py.File(filename,'r') as infile:
#         infile.visititems(print_attrs)
#         print('-------------------')
#         print("attributes for the root file")
#         print('-------------------')
#         for key,value in infile.attrs.items():
#             print("attribute name: ",key,"--- value: ",value)
#     return None
#
# if __name__ == "__main__":
#     #
#     # if we are tunning as main program pass filename as argument
#     #
#     parser = argparse.ArgumentParser()
#     parser.add_argument('h5_file',type=str,help='name of h5 file')
#     args=parser.parse_args()
#     filename=args.h5_file
#     dumph5(filename)
#
# ```

# %% [markdown]
# Take a look at the Level3 mapped dataset specification:  http://oceancolor.gsfc.nasa.gov/DOCS/Ocean_Level-3_SMI_Products.pdf
# Compare that specification with the data dump given by dumph5:  (a reference page on the data type notation for h5py: https://www.safaribooksonline.com/library/view/python-and-hdf5/9781491944981/ch07.html and for numpy:http://docs.scipy.org/doc/numpy/reference/arrays.dtypes.html).

# %%
mapped_file=glob.glob('/Users/alena/Dropbox/UBC/e582files/01_13_15/dataset/A20130322013059.L3m_MO_CHL_chlor_a_9km.h5')[0]
dumph5(mapped_file)
# Out:
# item name:  l3m_data <HDF5 dataset "l3m_data": shape (2160, 4320), type ">f4">
#     Fill: -32767.0
#     Scaling: linear
#     Scaling Equation: (Slope*l3m_data) + Intercept = Parameter value
#     Slope: 1.0
#     Intercept: 0.0
#     HDF4_OBJECT_TYPE: SDS
#     HDF4_OBJECT_NAME: l3m_data
#     HDF4_REF_NUM: 2
# -------------------
# attributes for the root file
# -------------------
# attribute name:  Product Name_GLOSDS --- value:  A20130322013059.L3m_MO_CHL_chlor_a_9km
# attribute name:  Sensor Name_GLOSDS --- value:  HMODISA
# attribute name:  Sensor_GLOSDS --- value:
# attribute name:  Title_GLOSDS --- value:  HMODISA Level-3 Standard Mapped Image
# attribute name:  Data Center_GLOSDS --- value:
# attribute name:  Station Name_GLOSDS --- value:
# attribute name:  Station Latitude_GLOSDS --- value:  0.0
# attribute name:  Station Longitude_GLOSDS --- value:  0.0
# attribute name:  Mission_GLOSDS --- value:
# attribute name:  Mission Characteristics_GLOSDS --- value:
# attribute name:  Sensor Characteristics_GLOSDS --- value:
# attribute name:  Product Type_GLOSDS --- value:  other
# attribute name:  Processing Version_GLOSDS --- value:  2013.1
# attribute name:  Software Name_GLOSDS --- value:  smigen
# attribute name:  Software Version_GLOSDS --- value:  4.42
# attribute name:  Processing Time_GLOSDS --- value:  2013270170823000
# attribute name:  Input Files_GLOSDS --- value:  A20130322013059.L3b_MO_CHL.main
# attribute name:  Processing Control_GLOSDS --- value:  smigen par=A20130322013059.L3m_MO_CHL_chlor_a_9km.param
# attribute name:  Input Parameters_GLOSDS --- value:  IFILE = /data4/sdpsoper/vdc/vpu7/workbuf/A20130322013059.L3b_MO_CHL.main|OFILE = A20130322013059.L3m_MO_CHL_chlor_a_9km|PFILE = |PROD = chlor_a|PALFILE = DEFAULT|PROCESSING VERSION = 2013.1|MEAS = 1|STYPE = 0|DATAMIN = 0.000000|DATAMAX = 0.000000|LONWEST = -180.000000|LONEAST = 180.000000|LATSOUTH = -90.000000|LATNORTH = 90.000000|RESOLUTION = 9km|PROJECTION = RECT|GAP_FILL = 0|SEAM_LON = -180.000000|PRECISION=F
# attribute name:  L2 Flag Names_GLOSDS --- value:  ATMFAIL,LAND,HILT,HISATZEN,STRAYLIGHT,CLDICE,COCCOLITH,LOWLW,CHLWARN,CHLFAIL,NAVWARN,MAXAERITER,ATMWARN,HISOLZEN,NAVFAIL,FILTER,HIGLINT
# attribute name:  Period Start Year_GLOSDS --- value:  2013
# attribute name:  Period Start Day_GLOSDS --- value:  32
# attribute name:  Period End Year_GLOSDS --- value:  2013
# attribute name:  Period End Day_GLOSDS --- value:  59
# attribute name:  Start Time_GLOSDS --- value:  2013032002508693
# attribute name:  End Time_GLOSDS --- value:  2013060030007181
# attribute name:  Start Year_GLOSDS --- value:  2013
# attribute name:  Start Day_GLOSDS --- value:  32
# attribute name:  Start Millisec_GLOSDS --- value:  1508693
# attribute name:  End Year_GLOSDS --- value:  2013
# attribute name:  End Day_GLOSDS --- value:  60
# attribute name:  End Millisec_GLOSDS --- value:  10807181
# attribute name:  Start Orbit_GLOSDS --- value:  57169
# attribute name:  End Orbit_GLOSDS --- value:  57578
# attribute name:  Orbit_GLOSDS --- value:  57373
# attribute name:  Map Projection_GLOSDS --- value:  Equidistant Cylindrical
# attribute name:  Latitude Units_GLOSDS --- value:  degrees North
# attribute name:  Longitude Units_GLOSDS --- value:  degrees East
# attribute name:  Northernmost Latitude_GLOSDS --- value:  90.0
# attribute name:  Southernmost Latitude_GLOSDS --- value:  -90.0
# attribute name:  Westernmost Longitude_GLOSDS --- value:  -180.0
# attribute name:  Easternmost Longitude_GLOSDS --- value:  180.0
# attribute name:  Latitude Step_GLOSDS --- value:  0.0833333
# attribute name:  Longitude Step_GLOSDS --- value:  0.0833333
# attribute name:  SW Point Latitude_GLOSDS --- value:  -89.9583
# attribute name:  SW Point Longitude_GLOSDS --- value:  -179.958
# attribute name:  Data Bins_GLOSDS --- value:  13451607
# attribute name:  Number of Lines_GLOSDS --- value:  2160
# attribute name:  Number of Columns_GLOSDS --- value:  4320
# attribute name:  Parameter_GLOSDS --- value:  Chlorophyll a concentration
# attribute name:  Measure_GLOSDS --- value:  Mean
# attribute name:  Units_GLOSDS --- value:  mg m^-3
# attribute name:  Scaling_GLOSDS --- value:  linear
# attribute name:  Scaling Equation_GLOSDS --- value:  (Slope*l3m_data) + Intercept = Parameter value
# attribute name:  Slope_GLOSDS --- value:  1.0
# attribute name:  Intercept_GLOSDS --- value:  0.0
# attribute name:  Data Minimum_GLOSDS --- value:  0.00049
# attribute name:  Data Maximum_GLOSDS --- value:  99.1708
# attribute name:  Suggested Image Scaling Minimum_GLOSDS --- value:  0.01
# attribute name:  Suggested Image Scaling Maximum_GLOSDS --- value:  20.0
# attribute name:  Suggested Image Scaling Type_GLOSDS --- value:  LOG
# attribute name:  Suggested Image Scaling Applied_GLOSDS --- value:  No
# attribute name:  _lastModified_GLOSDS --- value:  2013270170823000
# attribute name:  Conventions_GLOSDS --- value:  CF-1.6
# attribute name:  institution_GLOSDS --- value:  NASA/GSFC OBPG

# %%
with  h5py.File(mapped_file,'r') as infile:
    data=infile['l3m_data']
    print list(data.attrs)
    print(data)
    for key,value in data.attrs.items():
        print key,value
# Out:
# [u'Fill', u'Scaling', u'Scaling Equation', u'Slope', u'Intercept', u'HDF4_OBJECT_TYPE', u'HDF4_OBJECT_NAME', u'HDF4_REF_NUM']
# <HDF5 dataset "l3m_data": shape (2160, 4320), type ">f4">
# Fill -32767.0
# Scaling linear
# Scaling Equation (Slope*l3m_data) + Intercept = Parameter value
# Slope 1.0
# Intercept 0.0
# HDF4_OBJECT_TYPE SDS
# HDF4_OBJECT_NAME l3m_data
# HDF4_REF_NUM 2

# %%
with  h5py.File(mapped_file,'r') as infile:
    data=infile['l3m_data']
    #
    # use a dictionary comprehension to get the attributes for
    # the chlorophyll data
    #
    capture={key:value for key,value in data.attrs.items()}
    capture['parameter']=infile.attrs['Parameter_GLOSDS']
    capture['units']=infile.attrs['Units_GLOSDS']
    data=data[...]
    print(type(data))
    print(capture)
# Out:
# <type 'numpy.ndarray'>
# {u'Slope': 1.0, u'HDF4_OBJECT_TYPE': 'SDS', u'HDF4_OBJECT_NAME': 'l3m_data', u'Scaling': 'linear', u'Intercept': 0.0, u'Scaling Equation': '(Slope*l3m_data) + Intercept = Parameter value', 'units': 'mg m^-3', u'HDF4_REF_NUM': 2, 'parameter': 'Chlorophyll a concentration', u'Fill': -32767.0}

# %%
fig=plt.figure()
ax1=fig.add_subplot(111)
ax1.imshow(data)

# %%
fig=plt.figure()
ax1=fig.add_subplot(111)
out=ax1.hist(data.flat)

# %%
# histogram shows lots of missing values
# replace all data less than or equal to the fill value
# with nan
#
hit=data <= capture['Fill']
data[hit]=np.nan

# %%
fig=plt.figure()
ax1=fig.add_subplot(111)
ax1.imshow(data)

# %%
fig=plt.figure()
ax1=fig.add_subplot(111)
hit=np.logical_and(data > 0,data < 1)
out=ax1.hist(data[hit].flat)
# Out:
# -c:3: RuntimeWarning: invalid value encountered in greater
# -c:3: RuntimeWarning: invalid value encountered in less

# %%
fig=plt.figure(figsize=[12,12])
ax1=fig.add_subplot(111)
vals=ax1.imshow(np.log10(data))
fig.colorbar(vals)
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x11dc746c8>

# %%
data.shape
# Out:
# (2160, 4320)

# %%
numlats,numlons=data.shape
lats=np.linspace(90,-90,numlats)
lons=np.linspace(-180,180,numlons)

# %%
grid_lons,grid_lats=np.meshgrid(lons,lats)
small_lons=grid_lons[250:750,250:750]
small_lats=grid_lats[250:750,250:750]
small_data=data[250:750,250:750]
print(np.sum(np.isnan(small_data.flat)))
masked_data=np.ma.masked_where(np.isnan(small_data),small_data)
# Out:
# 114883

# %%
from mpl_toolkits.basemap import Basemap
lcc_values=dict(resolution='l',projection='lcc',
                lat_1=30,lat_2=50,lat_0=45,lon_0=-135,
                llcrnrlon=-150,llcrnrlat=30,
                urcrnrlon=-120,urcrnrlat=50)
proj=Basemap(**lcc_values)
# create figure, add axes
fig=plt.figure(figsize=(12, 12))
ax=fig.add_subplot(111)
## define parallels and meridians to draw.
parallels=np.arange(-90, 90, 5)
meridians=np.arange(0, 360, 5)
proj.drawparallels(parallels, labels=[1, 0, 0, 0],\
                  fontsize=10, latmax=90)
proj.drawmeridians(meridians, labels=[0, 0, 0, 1],\
                  fontsize=10, latmax=90)
# draw coast & fill continents
#map.fillcontinents(color=[0.25, 0.25, 0.25], lake_color=None) # coral
out=proj.drawcoastlines(linewidth=1.5, linestyle='solid', color='k')
x, y=proj(small_lons,small_lats)
print(x.shape,y.shape,data.shape)
CS=proj.pcolor(x, y, np.log10(masked_data), cmap=plt.cm.hot)
#
# now add the radar ground track to the image
#
CBar=proj.colorbar(CS, 'right', size='5%', pad='5%')
CBar.set_label('log10 (mg/m^3) of the chlorophyll a concentration (')
title=ax.set_title('Chlorophyll-a concentration')
fig.canvas.draw()
# Out:
# ((500, 500), (500, 500), (2160, 4320))
# /Users/alena/anaconda/lib/python2.7/site-packages/numpy/ma/core.py:797: RuntimeWarning: invalid value encountered in less_equal
#   return umath.less_equal(x, self.critical_value)

# %% [markdown]
# ##Binned data

# %% [markdown]
# 1. Take a look at http://oceancolor.gsfc.nasa.gov/cms/L3Bins.html which describes the binning scheme
# 2. Here is a description of the hdf file layout: http://oceancolor.gsfc.nasa.gov/DOCS/Ocean_Level-3_Binned_Data_Products.pdf

# %%
binned_file=glob.glob('/Users/alena/Dropbox/UBC/e582files/01_13_15/dataset/A20130322013059.L3b_MO_CHL.h5')[0]
dumph5(binned_file)
# Out:
# item name:  Level-3 Binned Data <HDF5 group "/Level-3 Binned Data" (8 members)>
#     HDF4_OBJECT_TYPE: Vgroup
#     HDF4_OBJECT_NAME: Level-3 Binned Data
#     HDF4_REF_NUM: 2
# item name:
#  Level-3 Binned Data/BinIndex <HDF5 dataset "BinIndex": shape (4320,), type "|V36">
#     TITLE: BinIndex
#     CLASS: TABLE
#     VERSION: 1.0
#     FIELD_0_NAME: row_num
#     FIELD_1_NAME: vsize
#     FIELD_2_NAME: hsize
#     FIELD_3_NAME: start_num
#     FIELD_4_NAME: begin
#     FIELD_5_NAME: extent
#     FIELD_6_NAME: max
#     HDF4_OBJECT_TYPE: Vdata
#     HDF4_OBJECT_NAME: BinIndex
#     HDF4_REF_NUM: 15707
# item name:  Level-3 Binned Data/BinIndex_t <HDF5 named type "BinIndex_t" (dtype |V36)>
# item name:  Level-3 Binned Data/BinList <HDF5 dataset "BinList": shape (13451607,), type "|V19">
#     TITLE: BinList
#     CLASS: TABLE
#     VERSION: 1.0
#     FIELD_0_NAME: bin_num
#     FIELD_1_NAME: nobs
#     FIELD_2_NAME: nscenes
#     FIELD_3_NAME: time_rec
#     FIELD_4_NAME: weights
#     FIELD_5_NAME: sel_cat
#     FIELD_6_NAME: flags_set
#     HDF4_OBJECT_TYPE: Vdata
#     HDF4_OBJECT_NAME: BinList
#     HDF4_REF_NUM: 4
# item name:  Level-3 Binned Data/BinList_t <HDF5 named type "BinList_t" (dtype |V19)>
# item name:  Level-3 Binned Data/SEAGrid <HDF5 dataset "SEAGrid": shape (1,), type "|V44">
#     TITLE: SEAGrid
#     CLASS: TABLE
#     VERSION: 1.0
#     FIELD_0_NAME: registration
#     FIELD_1_NAME: straddle
#     FIELD_2_NAME: bins
#     FIELD_3_NAME: radius
#     FIELD_4_NAME: max_north
#     FIELD_5_NAME: max_south
#     FIELD_6_NAME: seam_lon
#     HDF4_OBJECT_TYPE: Vdata
#     HDF4_OBJECT_NAME: SEAGrid
#     HDF4_REF_NUM: 3
# item name:  Level-3 Binned Data/SEAGrid_t <HDF5 named type "SEAGrid_t" (dtype |V44)>
# item name:  Level-3 Binned Data/chlor_a <HDF5 dataset "chlor_a": shape (13451607,), type "|V8">
#     TITLE: chlor_a
#     CLASS: TABLE
#     FIELD_0_NAME: chlor_a_sum
#     FIELD_1_NAME: chlor_a_sum_sq
#     HDF4_OBJECT_TYPE: Vdata
#     HDF4_OBJECT_NAME: chlor_a
#     HDF4_REF_NUM: 5
#     VERSION: 1.0
# item name:  Level-3 Binned Data/chlor_a_t <HDF5 named type "chlor_a_t" (dtype |V8)>
# -------------------
# attributes for the root file
# -------------------
# attribute name:  Product Name_GLOSDS --- value:  A20130322013059.L3b_MO_CHL.main
# attribute name:  Title_GLOSDS --- value:  HMODISA Level-3 Binned Data
# attribute name:  Sensor Name_GLOSDS --- value:  HMODISA
# attribute name:  Mission_GLOSDS --- value:
# attribute name:  Mission Characteristics_GLOSDS --- value:
# attribute name:  Sensor_GLOSDS --- value:
# attribute name:  Sensor Characteristics_GLOSDS --- value:
# attribute name:  Product Type_GLOSDS --- value:  other
# attribute name:  Processing Version_GLOSDS --- value:  2013.1
# attribute name:  Software Name_GLOSDS --- value:  L3BIN
# attribute name:  Software Version_GLOSDS --- value:  3.54
# attribute name:  Orbit_GLOSDS --- value:  57373
# attribute name:  Start Orbit_GLOSDS --- value:  57169
# attribute name:  End Orbit_GLOSDS --- value:  57578
# attribute name:  Processing Time_GLOSDS --- value:  2013270170746000
# attribute name:  Processing Control_GLOSDS --- value:  l3bin par=A20130322013059.L3b_MO_CHL.param
# attribute name:  Input Parameters_GLOSDS --- value:  INFILE = /data4/sdpsoper/vdc/vpu7/workbuf/l3inlist.dat|OFILE = A20130322013059.L3b_MO_CHL.main|PFILE = A20130322013059.L3b_MO_CHL.main|SYEAR = 2013|EYEAR = 2013|SDAY = 32|EDAY = 59|SORBIT = -1|EORBIT = -1|OUT_PARM = DEFAULT|TFLAG = O|PROCESSING VERSION = 2013.1|REDUCE_FAC = 1|MERGED = |LONEAST = 180.000000|LONWEST = -180.000000|LATNORTH = 90.000000|LATSOUTH = -90.000000|VERBOSE = 0|UNIT_WGT = 0|MEDIAN = 0|
# attribute name:  Input Files_GLOSDS --- value:  /data4/sdpsoper/vdc/vpu7/workbuf/A20130332013040.L3b_8D_CHL.main,/data4/sdpsoper/vdc/vpu7/workbuf/A20130412013048.L3b_8D_CHL.main,/data4/sdpsoper/vdc/vpu7/workbuf/A20130492013056.L3b_8D_CHL.main,/data4/sdpsoper/vdc/vpu7/workbuf/A2013032.L3b_DAY_CHL.main,/data4/sdpsoper/vdc/vpu7/workbuf/A2013057.L3b_DAY_CHL.main,/data4/sdpsoper/vdc/vpu7/workbuf/A2013058.L3b_DAY_CHL.main,/data4/sdpsoper/vdc/vpu7/workbuf/A2013059.L3b_DAY_CHL.main
# attribute name:  L2 Flag Names_GLOSDS --- value:  ATMFAIL,LAND,HILT,HISATZEN,STRAYLIGHT,CLDICE,COCCOLITH,LOWLW,CHLWARN,CHLFAIL,NAVWARN,MAXAERITER,ATMWARN,HISOLZEN,NAVFAIL,FILTER,HIGLINT
# attribute name:  Period Start Year_GLOSDS --- value:  2013
# attribute name:  Period Start Day_GLOSDS --- value:  32
# attribute name:  Period End Year_GLOSDS --- value:  2013
# attribute name:  Period End Day_GLOSDS --- value:  59
# attribute name:  Start Time_GLOSDS --- value:  2013032002508693
# attribute name:  End Time_GLOSDS --- value:  2013033030007862
# attribute name:  Start Year_GLOSDS --- value:  2013
# attribute name:  Start Day_GLOSDS --- value:  32
# attribute name:  Start Millisec_GLOSDS --- value:  1508693
# attribute name:  End Year_GLOSDS --- value:  2013
# attribute name:  End Day_GLOSDS --- value:  60
# attribute name:  End Millisec_GLOSDS --- value:  10807181
# attribute name:  Latitude Units_GLOSDS --- value:  degrees North
# attribute name:  Longitude Units_GLOSDS --- value:  degrees East
# attribute name:  Northernmost Latitude_GLOSDS --- value:  62.2708
# attribute name:  Southernmost Latitude_GLOSDS --- value:  -78.5208
# attribute name:  Easternmost Longitude_GLOSDS --- value:  179.979
# attribute name:  Westernmost Longitude_GLOSDS --- value:  -179.979
# attribute name:  Data Bins_GLOSDS --- value:  13451607
# attribute name:  Percent Data Bins_GLOSDS --- value:  56.6105
# attribute name:  Units_GLOSDS --- value:  chlor_a:mg m^-3
# attribute name:  Bin Resolution_GLOSDS --- value:  4 km

# %%
with  h5py.File(binned_file,'r') as infile:
    root_key=infile.keys()[0]
    print(root_key)
    print(infile[root_key].keys())
    print(infile[root_key]['chlor_a'])
    the_data=infile[root_key]['chlor_a']
    out=the_data[...]
# Out:
# Level-3 Binned Data
# [u'BinIndex', u'BinIndex_t', u'BinList', u'BinList_t', u'SEAGrid', u'SEAGrid_t', u'chlor_a', u'chlor_a_t']
# <HDF5 dataset "chlor_a": shape (13451607,), type "|V8">

# %% [markdown]
# Note that the chlorphyll data is stored as an 8 byte opaque type (V8).  On OSX, anaconda installs an hdf5 program call 'h5ls' which we can use to see more detail about this type.  On Windows, you'll need to install the utility separately
# http://www.hdfgroup.org/HDF5/release/obtain5.html

# %% [markdown]
# ``` bash
# phil@rail% h5ls -v -r A20101522010181.L3b_MO_CHL.h5
#
# /Level-3\ Binned\ Data/chlor_a Dataset {11384896/Inf}
#     Attribute: CLASS scalar
#         Type:      5-byte space-padded ASCII string
#         Data:  "TABLE"
#     Attribute: FIELD_0_NAME scalar
#         Type:      11-byte space-padded ASCII string
#         Data:  "chlor_a_sum"
#     Attribute: FIELD_1_NAME scalar
#         Type:      14-byte space-padded ASCII string
#         Data:  "chlor_a_sum_sq"
#     Attribute: HDF4_OBJECT_NAME scalar
#         Type:      7-byte space-padded ASCII string
#         Data:  "chlor_a"
#     Attribute: HDF4_OBJECT_TYPE scalar
#         Type:      5-byte space-padded ASCII string
#         Data:  "Vdata"
#     Attribute: HDF4_REF_NUM scalar
#         Type:      16-bit big-endian unsigned integer
#         Data:  5
#     Attribute: TITLE scalar
#         Type:      7-byte space-padded ASCII string
#         Data:  "chlor_a"
#     Attribute: VERSION scalar
#         Type:      3-byte space-padded ASCII string
#         Data:  "1.0"
#     Location:  1:216324552
#     Links:     1
#     Chunks:    {11384896} 91079168 bytes
#     Storage:   91079168 logical bytes, 91079168 allocated bytes, 100.00% utilization
#     Type:      shared-1:216324384 struct {
#                    "chlor_a_sum"      +0    IEEE 32-bit big-endian float
#                    "chlor_a_sum_sq"   +4    IEEE 32-bit big-endian float
#                } 8 bytes
# /Level-3\ Binned\ Data/chlor_a_t Type
#     Location:  1:216324384
#     Links:     2
#     Type:      shared-1:216324384 struct {
#                    "chlor_a_sum"      +0    IEEE 32-bit big-endian float
#                    "chlor_a_sum_sq"   +4    IEEE 32-bit big-endian float
#                } 8 bytes
# ```

# %% [markdown]
# h5py reads this 8 byte vector in as a vector of two 4 byte tuples.  The first is the total chorophyll and the second is the squared sum.  To get the mean and variance for the binned chlorophyll we need to write a function as described in
# Section 4 of http://oceancolor.gsfc.nasa.gov/DOCS/Ocean_Level-3_Binned_Data_Products.pdf

# %%
out[:10]
# Out:
# array([(1.0108546018600464, 0.7227351069450378),
#        (1.614138126373291, 1.3307397365570068),
#        (1.4797011613845825, 2.1895155906677246),
#        (3.128537178039551, 3.2786619663238525),
#        (1.5828938484191895, 1.7810276746749878),
#        (0.9621266722679138, 0.6559691429138184),
#        (1.5973378419876099, 1.2796920537948608),
#        (1.9252512454986572, 2.197010040283203),
#        (2.1689651012420654, 2.3599631786346436),
#        (2.617544174194336, 3.0093724727630615)],
#       dtype=[('chlor_a_sum', '>f4'), ('chlor_a_sum_sq', '>f4')])

# %% [markdown]
# ##Exercise

# %% [markdown]
# Write a function that calculates the mean chloryphyll concentration from level3 monthly binned file by extracting the weights from the binlist array and dividing each chlor_a_sum value by its weight.   Print out the first 50 non-zero chlorophyll concentrations in your file.

# %%
from __future__ import print_function
import glob  #this module gets file names using wildcards
#
# the h5dump.py file is one folder up in the utilities folder
# use site.addsitedir to add this folder to the list of folders
# python searches for imports
#
import site
site.addsitedir('../utilities')
from h5dump import dumph5
import h5py
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
binned_file=glob.glob('/Users/alena/Sync/UBC/classes/e582files_ch/01_13_15/dataset/A20130322013059.L3b_MO_CHL.h5')[0]
dumph5(binned_file);
# Out:
# item name:  Level-3 Binned Data <HDF5 group "/Level-3 Binned Data" (8 members)>
#     HDF4_OBJECT_TYPE: Vgroup
#     HDF4_OBJECT_NAME: Level-3 Binned Data
#     HDF4_REF_NUM: 2
# item name:  Level-3 Binned Data/BinIndex <HDF5 dataset "BinIndex": shape (4320,), type "|V36">
#     TITLE: BinIndex
#     CLASS: TABLE
#     VERSION: 1.0
#     FIELD_0_NAME: row_num
#     FIELD_1_NAME: vsize
#     FIELD_2_NAME: hsize
#     FIELD_3_NAME: start_num
#     FIELD_4_NAME: begin
#     FIELD_5_NAME: extent
#     FIELD_6_NAME: max
#     HDF4_OBJECT_TYPE: Vdata
#     HDF4_OBJECT_NAME: BinIndex
#     HDF4_REF_NUM: 15707
# item name:  Level-3 Binned Data/BinIndex_t <HDF5 named type "BinIndex_t" (dtype |V36)>
# item name:  Level-3 Binned Data/BinList <HDF5 dataset "BinList": shape (13451607,), type "|V19">
#     TITLE: BinList
#     CLASS: TABLE
#     VERSION: 1.0
#     FIELD_0_NAME: bin_num
#     FIELD_1_NAME: nobs
#     FIELD_2_NAME: nscenes
#     FIELD_3_NAME: time_rec
#     FIELD_4_NAME: weights
# ...

# %%
import tile_calc
dir(tile_calc)
# Out:
# ['__builtins__',
#  '__doc__',
#  '__file__',
#  '__name__',
#  '__package__',
#  'division',
#  'np',
#  'tile_calc']

# %%
test18=tile_calc.tile_calc(18)
print('lat lon bounds for tile 367: ',test18.tile2bounds(367))
print('bounds for 411: ',test18.tile2bounds(411))
print('bounds for 412: ',test18.tile2bounds(412))
print('central lat lon for 367: ',test18.tile2latlon(367))

# %%
#creating list of bins

with  h5py.File(binned_file,'r') as infile:
    root_key=infile.keys()[0]
    bin_num
print ('binnumlen: ',len(bin_num))
#binnums=binlist['bin_num'][:veclength]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fff7fdc330d6> in <module>()
#       1 with  h5py.File(binned_file,'r') as infile:
#       2     root_key=infile.keys()[0]
# ----> 3 print ('binnumlen: ',len(bin_num))
#       4 #binnums=binlist['bin_num'][:veclength]
#
# NameError: name 'bin_num' is not defined

# %%
array = [[]]

# %%
#creating a 3d index of lats, lons
import numpy 

cartarr = numpy.zeros((500,500,2))
print(cartarr[0,0,0])

lat = 75  
lon = -170
rows = 500
columns = 500
for i in range(rows):
    for j in range(columns):
        cartarr[i][j][1] = lon
        lon = lon + .1
        cartarr [i][j][0] = lat
    lat = lat - .1

#testing array populations
print(cartarr[0,250,1])
print(cartarr[250,75,0])
# Out:
# 0.0
# -145.0
# 50.0

# %%
test18=tile_calc.tile_calc(18)
lat = cartarr[250,75,0]
print(lat)

lat = 0
rows = 500
columns = 500
for i in range(rows):
    for j in range(columns):
        lat = cartarr[i][j][0]
        print(lat)

#test18.latlon2tile(cartarr[0,250,1],-123.25))
# Out:
# 50.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# 75.0
# ...
